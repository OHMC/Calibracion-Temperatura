# %%
import sys
sys.path.append("/home/sagus/Development/Calibracion-Temperatura/src")

# %%
import metricas as mt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## LH

# %%
wrf_LH_A = pd.read_pickle('../pickles/lh_wrf_A')
wrf_LH_B = pd.read_pickle('../pickles/lh_wrf_B')
wrf_LH_C = pd.read_pickle('../pickles/lh_wrf_c')
wrf_LH_D = pd.read_pickle('../pickles/lh_wrf_D')

# %%
base = '/home/sagus/Development/Calibracion-Temperatura/datasets/'
filename = 'omixom_LH.csv'
path = f"{base}{filename}"
aws_LH = mt.fromCSVtoDF(path)

# %%
dfTmp_LH_A = mt.getAWSvsWRF(wrf_LH_A, aws_LH, 'LH', 'A')
dfTmp_LH_B = mt.getAWSvsWRF(wrf_LH_B, aws_LH, 'LH', 'B')
dfTmp_LH_C = mt.getAWSvsWRF(wrf_LH_C, aws_LH, 'LH', 'C')
dfTmp_LH_D = mt.getAWSvsWRF(wrf_LH_D, aws_LH, 'LH', 'D')
# Out:
# Index Error: Timestamp('2019-12-10 16:00:00')
# Index Error: Timestamp('2020-03-17 05:00:00')
# Index Error: Timestamp('2020-03-17 06:00:00')
# Index Error: Timestamp('2020-03-17 07:00:00')
# Index Error: Timestamp('2020-03-17 08:00:00')
# Index Error: Timestamp('2020-03-17 09:00:00')
# Index Error: Timestamp('2020-03-17 10:00:00')
# Index Error: Timestamp('2020-03-17 11:00:00')
# Index Error: Timestamp('2020-03-17 13:00:00')
# Index Error: Timestamp('2020-03-17 14:00:00')
# Index Error: Timestamp('2020-03-17 15:00:00')
# Index Error: Timestamp('2020-03-17 16:00:00')
# Index Error: Timestamp('2020-03-17 17:00:00')
# Index Error: Timestamp('2020-03-17 18:00:00')
# Index Error: Timestamp('2020-03-17 19:00:00')
# Index Error: Timestamp('2020-03-17 20:00:00')
# Index Error: Timestamp('2020-03-17 21:00:00')
# Index Error: Timestamp('2020-03-17 22:00:00')
# Index Error: Timestamp('2020-03-17 23:00:00')
# Index Error: Timestamp('2020-03-18 00:00:00')
# ...

# %%
data_LH_A, rmse_LH_A, mae_LH_A = mt.getMetricas(dfTmp_LH_A, 'LH', 'A')
data_LH_B, rmse_LH_B, mae_LH_B = mt.getMetricas(dfTmp_LH_B, 'LH', 'B')
data_LH_C, rmse_LH_C, mae_LH_C = mt.getMetricas(dfTmp_LH_C, 'LH', 'C')
data_LH_D, rmse_LH_D, mae_LH_D = mt.getMetricas(dfTmp_LH_D, 'LH', 'D')

# %% [markdown]
# ## UBP

# %%
wrf_ubp_A = pd.read_pickle('../pickles/T2_A_UBP')
wrf_ubp_B = pd.read_pickle('../pickles/T2_B_UBP')
wrf_ubp_C = pd.read_pickle('../pickles/T2_C_UBP')
wrf_ubp_D = pd.read_pickle('../pickles/T2_D_UBP')

# %%
filename = 'omixom_UBP.csv'
path = f"{base}{filename}"
aws_UBP = mt.fromCSVtoDF(path)

# %%
dfTmp_UBP_A = mt.getAWSvsWRF(wrf_ubp_A, aws_UBP, 'UBP', 'A')
dfTmp_UBP_B = mt.getAWSvsWRF(wrf_ubp_B, aws_UBP, 'UBP', 'B')
dfTmp_UBP_C = mt.getAWSvsWRF(wrf_ubp_C, aws_UBP, 'UBP', 'C')
dfTmp_UBP_D = mt.getAWSvsWRF(wrf_ubp_D, aws_UBP, 'UBP', 'D')
# Out:
# Index Error: Timestamp('2020-03-25 10:00:00')
# Index Error: Timestamp('2020-03-25 11:00:00')
# Index Error: Timestamp('2020-03-26 06:00:00')
# Index Error: Timestamp('2020-03-26 07:00:00')
# Index Error: Timestamp('2020-03-26 08:00:00')
# Index Error: Timestamp('2020-04-07 10:00:00')
# Index Error: Timestamp('2020-04-14 07:00:00')
# Index Error: Timestamp('2020-04-14 08:00:00')
# Index Error: Timestamp('2020-04-15 00:00:00')
# Index Error: Timestamp('2020-04-15 01:00:00')
# Index Error: Timestamp('2020-04-15 02:00:00')
# Index Error: Timestamp('2020-04-15 03:00:00')
# Index Error: Timestamp('2020-04-15 04:00:00')
# Index Error: Timestamp('2020-04-15 05:00:00')
# Index Error: Timestamp('2020-04-15 06:00:00')
# Index Error: Timestamp('2020-04-15 07:00:00')
# Index Error: Timestamp('2020-04-15 08:00:00')
# Index Error: Timestamp('2020-04-16 06:00:00')
# Index Error: Timestamp('2020-04-16 07:00:00')
# Index Error: Timestamp('2020-04-16 08:00:00')
# ...

# %%
data_UBP_A, rmse_UBP_A, mae_UBP_A = mt.getMetricas(dfTmp_UBP_A, 'UBP', 'A')
data_UBP_B, rmse_UBP_B, mae_UBP_B = mt.getMetricas(dfTmp_UBP_B, 'UBP', 'B')
data_UBP_C, rmse_UBP_C, mae_UBP_C = mt.getMetricas(dfTmp_UBP_C, 'UBP', 'C')
data_UBP_D, rmse_UBP_D, mae_UBP_D = mt.getMetricas(dfTmp_UBP_D, 'UBP', 'D')

# %% [markdown]
# ## EPEC

# %%
wrf_epec_A = pd.read_pickle('../pickles/T2_A_EPEC')
wrf_epec_B = pd.read_pickle('../pickles/T2_B_EPEC')
wrf_epec_C = pd.read_pickle('../pickles/T2_C_EPEC')
wrf_epec_D = pd.read_pickle('../pickles/T2_D_EPEC')

# %%
filename = 'omixom_EPEC.csv'
path = f"{base}{filename}"
aws_EPEC = mt.fromCSVtoDF(path)

# %%
dfTmp_EPEC_A = mt.getAWSvsWRF(wrf_epec_A, aws_EPEC, 'EPEC', 'A')
dfTmp_EPEC_B = mt.getAWSvsWRF(wrf_epec_B, aws_EPEC, 'EPEC', 'B')
dfTmp_EPEC_C = mt.getAWSvsWRF(wrf_epec_C, aws_EPEC, 'EPEC', 'C')
dfTmp_EPEC_D = mt.getAWSvsWRF(wrf_epec_D, aws_EPEC, 'EPEC', 'D')
# Out:
# Index Error: Timestamp('2020-02-08 03:00:00')
# Index Error: Timestamp('2020-02-08 04:00:00')
# Index Error: Timestamp('2020-02-08 05:00:00')
# Index Error: Timestamp('2020-02-08 06:00:00')
# Index Error: Timestamp('2020-02-08 07:00:00')
# Index Error: Timestamp('2020-02-08 08:00:00')
# Index Error: Timestamp('2020-02-08 09:00:00')
# Index Error: Timestamp('2020-02-08 10:00:00')
# Index Error: Timestamp('2020-02-08 11:00:00')
# Index Error: Timestamp('2020-02-08 12:00:00')
# Index Error: Timestamp('2020-02-08 13:00:00')
# Index Error: Timestamp('2020-02-08 14:00:00')
# Index Error: Timestamp('2020-02-08 15:00:00')
# Index Error: Timestamp('2020-02-09 05:00:00')
# Index Error: Timestamp('2020-02-09 06:00:00')
# Index Error: Timestamp('2020-02-09 07:00:00')
# Index Error: Timestamp('2020-02-09 08:00:00')
# Index Error: Timestamp('2020-02-09 09:00:00')
# Index Error: Timestamp('2020-02-09 10:00:00')
# Index Error: Timestamp('2020-02-09 11:00:00')
# ...

# %%
data_EPEC_A, rmse_EPEC_A, mae_EPEC_A = mt.getMetricas(dfTmp_EPEC_A, 'EPEC', 'A')
data_EPEC_B, rmse_EPEC_B, mae_EPEC_B = mt.getMetricas(dfTmp_EPEC_B, 'EPEC', 'B')
data_EPEC_C, rmse_EPEC_C, mae_EPEC_C = mt.getMetricas(dfTmp_EPEC_C, 'EPEC', 'C')
data_EPEC_D, rmse_EPEC_D, mae_EPEC_D = mt.getMetricas(dfTmp_EPEC_D, 'EPEC', 'D')

# %% [markdown]
# ## Villa Retiro

# %%
wrf_vr_A = pd.read_pickle('../pickles/T2_A_VR')
wrf_vr_B = pd.read_pickle('../pickles/T2_B_VR')
wrf_vr_C = pd.read_pickle('../pickles/T2_C_VR')
wrf_vr_D = pd.read_pickle('../pickles/T2_D_VR')

# %%
filename = 'omixom_Bower.csv'
path = f"{base}{filename}"
aws_vr = mt.fromCSVtoDF(path)

# %%
dfTmp_VR_A = mt.getAWSvsWRF(wrf_vr_A, aws_vr, 'Villa Retiro', 'A')
dfTmp_VR_B = mt.getAWSvsWRF(wrf_vr_B, aws_vr, 'Villa Retiro', 'B')
dfTmp_VR_C = mt.getAWSvsWRF(wrf_vr_C, aws_vr, 'Villa Retiro', 'C')
dfTmp_VR_D = mt.getAWSvsWRF(wrf_vr_D, aws_vr, 'Villa Retiro', 'D')
# Out:
# Index Error: Timestamp('2019-06-01 15:00:00')
# Index Error: Timestamp('2019-06-01 16:00:00')
# Index Error: Timestamp('2019-06-01 17:00:00')
# Index Error: Timestamp('2019-06-01 18:00:00')
# Index Error: Timestamp('2019-06-01 19:00:00')
# Index Error: Timestamp('2019-06-01 20:00:00')
# Index Error: Timestamp('2019-06-01 21:00:00')
# Index Error: Timestamp('2019-06-01 22:00:00')
# Index Error: Timestamp('2019-06-01 23:00:00')
# Index Error: Timestamp('2019-06-02 00:00:00')
# Index Error: Timestamp('2019-06-02 01:00:00')
# Index Error: Timestamp('2019-06-02 02:00:00')
# Index Error: Timestamp('2019-06-02 03:00:00')
# Index Error: Timestamp('2019-06-02 04:00:00')
# Index Error: Timestamp('2019-06-02 05:00:00')
# Index Error: Timestamp('2019-06-02 06:00:00')
# Index Error: Timestamp('2019-06-02 07:00:00')
# Index Error: Timestamp('2019-06-02 08:00:00')
# Index Error: Timestamp('2019-06-02 09:00:00')
# Index Error: Timestamp('2019-06-02 10:00:00')
# ...

# %%
data_VR_A, rmse_VR_A, mae_VR_A = mt.getMetricas(dfTmp_VR_A, 'Villa Retiro', 'A')
data_VR_B, rmse_VR_B, mae_VR_B = mt.getMetricas(dfTmp_VR_B, 'Villa Retiro', 'B')
data_VR_C, rmse_VR_C, mae_VR_C = mt.getMetricas(dfTmp_VR_C, 'Villa Retiro', 'C')
data_VR_D, rmse_VR_D, mae_VR_D = mt.getMetricas(dfTmp_VR_D, 'Villa Retiro', 'D')

# %% [markdown]
# ## PLOT

# %%
import matplotlib as mpl

mpl.style.use('seaborn')
ax = plt.gca()

data_LH_A.plot(kind='line', ax=ax, color='#D1FDFF')
data_LH_B.plot(kind='line', ax=ax, color='#2A9DF4')
data_LH_C.plot(kind='line', ax=ax, color='#127BCD')
data_LH_D.plot(kind='line', ax=ax, color='#03254C')

data_VR_A.plot(kind='line', ax=ax, color='#9CCC9C')
data_VR_B.plot(kind='line', ax=ax, color='#649568')
data_VR_C.plot(kind='line', ax=ax, color='#0E6B0E')
data_VR_D.plot(kind='line', ax=ax, color='#149414')

data_UBP_A.plot(kind='line', ax=ax, color='#FFF192')
data_UBP_B.plot(kind='line', ax=ax, color='#FFEA61')
data_UBP_C.plot(kind='line', ax=ax, color='#FFDD3C')
data_UBP_D.plot(kind='line', ax=ax, color='#FFD400')

data_EPEC_A.plot(kind='line', ax=ax, color='#E5E5E5')
data_EPEC_B.plot(kind='line', ax=ax, color='#CCCCCC')
data_EPEC_C.plot(kind='line', ax=ax, color='#B2B2B2')
data_EPEC_D.plot(kind='line', ax=ax, figsize=(17,11), color='#8C8C8C')

plt.xlabel('Hora (UTC)')
plt.ylabel('Error (WRF - AWS) K')
plt.title('Grafico de errores de temperatura en territorio URBANO')
# Out:
# Text(0.5, 1.0, 'Grafico de errores de temperatura en territorio URBANO')

# %%
dfIndices = pd.DataFrame({
    'wrf':['WRF_A', 'WRF_B', 'WRF_C', 'WRF_D'],
    'RMSE LH': [rmse_LH_A, rmse_LH_B, rmse_LH_C, rmse_LH_D],
    'RMSE UBP': [rmse_UBP_A, rmse_UBP_B, rmse_UBP_C, rmse_UBP_D],
    'RMSE EPEC': [rmse_EPEC_A, rmse_EPEC_B, rmse_EPEC_C, rmse_EPEC_D],
    'RMSE VR': [rmse_VR_A, rmse_VR_B, rmse_VR_C, rmse_VR_D],
    'MAE LH': [mae_LH_A, mae_LH_B, mae_LH_C, mae_LH_D],
    'MAE UBP': [mae_UBP_A, mae_UBP_B, mae_UBP_C, mae_UBP_D],
    'MAE EPEC': [mae_EPEC_A, mae_EPEC_B, mae_EPEC_C, mae_EPEC_D],
    'MAE VR': [mae_VR_A, mae_VR_B, mae_VR_C, mae_VR_D]
})

dfIndices
# Out:
#      wrf   RMSE LH  RMSE UBP  RMSE EPEC   RMSE VR    MAE LH   MAE UBP  \
# 0  WRF_A  3.965408  5.336622   3.695032  6.531675  3.236468  4.563036
# 1  WRF_B  3.869779  5.028803   3.674301  6.104485  3.130714  4.324554
# 2  WRF_C  4.047698  5.243485   3.630102  6.461177  3.338295  4.507850
# 3  WRF_D  3.755661  4.961520   3.679347  6.032966  3.026760  4.246188
#
#    MAE EPEC    MAE VR
# 0  2.971596  5.476432
# 1  2.938842  5.115631
# 2  2.980152  5.380086
# 3  2.926716  5.026824
